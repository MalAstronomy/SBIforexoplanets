# %%
import numpy as np
import pandas as pd
import csv

# %%
from sklearn.metrics import roc_curve

# %%
ss=[]
lp=[]

for i in ['100']:
    s= pd.read_csv('/home/mvasist/samples/1/'+ i +'ksamples__resnet_e95_SBI_100ksim_TintLkIRLg.csv')   #waiting for this to be saved 
    ss.append(s.values)
    ln = pd.read_csv('/home/mvasist/samples/1/'+ i +'klnprob__resnet_e95_SBI_100ksim_TintLkIRLg.csv')   #waiting for this to be saved 
    lp.append(ln.values)

sss= np.vstack(ss)
samples = pd.DataFrame(sss)
lll= np.vstack(lp)
log_probability = pd.DataFrame(lll)

# %%
samples
# Out:
#              0          1         2         3
# 0          1.0  656.45703 -1.478516  2.350233
# 1          2.0  659.59235 -1.508702  2.335082
# 2          3.0  659.48580 -1.464517  2.405787
# 3          4.0  659.58060 -1.490735  2.279750
# 4          5.0  664.84454 -1.523047  2.450851
# ...        ...        ...       ...       ...
# 99994  99995.0  822.53845 -2.404268  2.543493
# 99995  99996.0  816.94525 -2.354554  2.605238
# 99996  99997.0  824.91345 -2.410438  2.640755
# 99997  99998.0  834.84340 -2.455547  2.600224
# 99998  99999.0  824.76370 -2.398262  2.707929
#
# [99999 rows x 4 columns]

# %%
log_probability
# Out:
#              0         1
# 0          1.0 -1.294897
# 1          2.0 -1.883967
# 2          3.0 -1.693084
# 3          4.0 -1.669467
# 4          5.0 -2.417622
# ...        ...       ...
# 99994  99995.0 -2.064807
# 99995  99996.0 -0.578377
# 99996  99997.0 -0.973761
# 99997  99998.0 -0.971395
# 99998  99999.0 -1.950781
#
# [99999 rows x 2 columns]

# %%
log_probability.iloc[:,[1]]
# Out:
#               1
# 0     -1.294897
# 1     -1.883967
# 2     -1.693084
# 3     -1.669467
# 4     -2.417622
# ...         ...
# 99994 -2.064807
# 99995 -0.578377
# 99996 -0.973761
# 99997 -0.971395
# 99998 -1.950781
#
# [99999 rows x 1 columns]

# %%
fpr, tpr, _= roc_curve(samples.iloc[:,[1,2,3]], log_probability.iloc[:,[1]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-da8554452884> in <module>()
# ----> 1 fpr, tpr, _= roc_curve(samples.iloc[:,[1,2,3]], log_probability.iloc[:,[1]])
#
# /home/mvasist/anaconda3/envs/petitRT/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /home/mvasist/anaconda3/envs/petitRT/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     912     """
#     913     fps, tps, thresholds = _binary_clf_curve(
# --> 914         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     915
# ...
